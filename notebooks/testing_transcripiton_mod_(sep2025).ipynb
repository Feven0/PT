# %%
! pip install genai
# Out:
# ...
#   Using cached openai-0.27.10-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached openai-0.27.10-py3-none-any.whl (76 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.108.2
#     Uninstalling openai-1.108.2:
#       Successfully uninstalled openai-1.108.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# instructor 1.10.0 requires openai<2.0.0,>=1.70.0, but you have openai 0.27.10 which is incompatible.
# litellm 1.74.8 requires openai>=1.68.2, but you have openai 0.27.10 which is incompatible.
# litellm 1.74.8 requires tiktoken>=0.7.0, but you have tiktoken 0.3.3 which is incompatible.
# pyautogen 0.2.35 requires openai>=1.3, but you have openai 0.27.10 which is incompatible.
# ...

# %%
from google import genai

client = genai.Client()

myfile = client.files.upload(file="/sample.mp3")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents=["Describe this audio clip", myfile]
)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google import genai
#       3 client = genai.Client()
#       5 myfile = client.files.upload(file="/sample.mp3")
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %%
! pip install openai

# %%
from openai import OpenAI
import sys
sys.path.insert(0, "/home/rehmet/tenx_ipersona")
# from tenx_ipersona.api.services.secret import get_auth
# # import openai

# OPENAI_API_KEY  = get_auth(ssmkey='OPENAI_PARROT_API_KEY')
openai_client = OpenAI(api_key="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" )
# openai.api_key = api_key=OPENAI_API_KEY
client = OpenAI()
audio_file= open("./sample.mp3", "rb")

transcription = client.audio.transcriptions.create(
    model="gpt-4o-transcribe", 
    file=audio_file
)

print(transcription.text)
# Out:
# 안녕하세요.

# %%
! pip install "livekit-agents[google]~=1.2"
# Out:
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached openai-1.108.2-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.2/594.2 kB 37.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 80.4 MB/s  0:00:00
# ...
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# ...
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached openai-1.108.2-py3-none-any.whl (948 kB)
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.1
#     Uninstalling psutil-5.9.1:
#       Successfully uninstalled psutil-5.9.1
#   Attempting uninstall: protobuf━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/28 [psutil]
#     Found existing installation: protobuf 4.25.4━━━━━━━━━━━━━━  2/28 [psutil]
#     Uninstalling protobuf-4.25.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/28 [psutil]
# ...

# %%
from livekit.plugins import google

session = AgentSession(
    llm=google.LLM(
        model="gemini-2.0-flash-exp",
    ),
    # ... tts, stt, vad, turn_detection, etc.
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from livekit.plugins import google
# ----> 3 session = AgentSession(
#       4     llm=google.LLM(
#       5         model="gemini-2.0-flash-exp",
#       6     ),
#       7     # ... tts, stt, vad, turn_detection, etc.
#       8 )
#
# NameError: name 'AgentSession' is not defined
